# %%
import matplotlib.pyplot as plt

# Data extracted from Ansible output (example values)
req_sec_values = {
    1: [571.10],
    2: [528.97],
    4: [516.62],
    8: [529.27]
}

# Flatten 'Req/Sec' values
flatten_req_sec_values = [value for values in req_sec_values.values() for value in values]

# Create a histogram
plt.hist(flatten_req_sec_values, bins=5, alpha=0.7, label=['1 instance', '2 instances', '4 instances', '8 instances'])
plt.xlabel('Req/Sec')
plt.ylabel('Frequency')
plt.title('Histogram of Req/Sec for Different Numbers of Instances')D
plt.grid(True)
plt.show()
